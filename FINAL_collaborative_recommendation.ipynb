# %% [markdown]
# <a href="https://colab.research.google.com/github/dangni02/dacos_rec/blob/main/collaborative_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 로드
restaurant_data = pd.read_csv('/content/drive/MyDrive/DACOS/df_meal.csv')
cafe_data = pd.read_csv('/content/drive/MyDrive/DACOS/df_cafe.csv')

# 태그 옵션 정의 (술집 관련 태그를 식당에 통합)
tag_options = {
    '식당': {
        '맛': ['음식이 맛있어요', '빵이 맛있어요'],
        '특별한 메뉴': ['특별한 메뉴가 있어요'],
        '메뉴 다양성': ['메뉴 구성이 알차요'],
        '신선도': ['재료가 신선해요', '잡내가 적어요', '고기 질이 좋아요'],
        '가성비': ['가성비가 좋아요', '양이 많아요'],
        '서비스': ['친절해요', '반찬이 잘 나와요', '음식이 빨리 나와요', '포장이 깔끔해요'],
        '청결': ['매장이 청결해요', '화장실이 깨끗해요'],
        '혼밥' : ['혼밥하기 좋아요'],
        # 술집 관련 태그를 식당에 통합
        '다양한 술': ['술이 다양해요'],
        '분위기': ['음악이 좋아요', '아늑해요', '인테리어가 멋져요'],
        '대화하기 좋음': ['대화하기 좋아요']
    },
    '카페': {
        '커피': ['커피가 맛있어요'],
        '디저트': ['디저트가 맛있어요'],
        '청결': ['매장이 청결해요', '화장실이 깨끗해요'],
        '서비스': ['친절해요', '포장이 깔끔해요'],
        '분위기': ['아늑해요', '인테리어가 멋져요'],
        '공부하기 좋음': ['집중하기 좋아요', '좌석이 편해요', '매장이 넓어요']
    }
}

# 식당만 고정된 음식 종류
category_options = {
    '식당': ['한식', '중식', '일식', '양식', '육류', '아시안음식', '샐러드']
}

# 사용자 입력 처리 함수 (다중 선택)
def get_user_selection_multi(prompt, choices):
    """
    사용자로부터 다중 선택을 받는 함수
    - prompt: 사용자에게 보여줄 메시지
    - choices: 선택지 리스트

    Returns:
    - selected_choices: 사용자가 선택한 항목들의 리스트
    """
    while True:
        print(prompt)
        for i, choice in enumerate(choices, 1):
            print(f"{i}. {choice}")
        try:
            selections = input("선택 번호를 입력하세요 (쉼표로 구분): ")
            selected_indices = [int(x.strip()) - 1 for x in selections.split(',')]
            if all(0 <= idx < len(choices) for idx in selected_indices):
                selected_choices = [choices[idx] for idx in selected_indices]
                return selected_choices
            else:
                print(f"잘못된 입력입니다. 1부터 {len(choices)} 사이의 숫자를 입력하세요.")
        except ValueError:
            print("숫자와 쉼표만 입력하세요.")

# 새로운 랭킹 함수 (다중 태그 지원)
def rank_stores_custom_multi(data, selected_tags, tag_options):
    """
    선택한 태그들을 기준으로 가게들을 랭킹하는 함수
    - 전체적인 태그 리뷰 수: 50%
    - 절대적 해당 키워드 태그 리뷰 수: 30%
    - 상대적 해당 키워드 태그 리뷰 수: 20%

    Parameters:
    - data: 필터링된 데이터프레임
    - selected_tags: 사용자가 선택한 태그 리스트
    - tag_options: 선택한 카테고리의 태그 옵션 딕셔너리

    Returns:
    - ranked_data: 랭킹된 데이터프레임 (최소 7개 이상)
    """

    # 선택한 태그에 해당하는 리뷰 컬럼들 가져오기
    selected_phrases = []
    for tag in selected_tags:
        selected_phrases.extend(tag_options[tag])

    # 절대적 해당 키워드 태그 리뷰 수 계산
    data['Selected_Tag_Absolute'] = data[selected_phrases].sum(axis=1)

    # 전체적인 태그 리뷰 수 (이미 '태그 총합' 컬럼에 있음)
    data['Overall_Tag_Count'] = data['태그 총합']

    # 상대적 해당 키워드 태그 리뷰 수 계산
    data['Selected_Tag_Relative'] = data['Selected_Tag_Absolute'] / data['Overall_Tag_Count']

    # 각 기준을 정규화 (0 ~ 1 범위)
    data['Overall_Tag_Normalized'] = data['Overall_Tag_Count'] / data['Overall_Tag_Count'].max()
    data['Selected_Tag_Absolute_Normalized'] = data['Selected_Tag_Absolute'] / data['Selected_Tag_Absolute'].max()
    data['Selected_Tag_Relative_Normalized'] = data['Selected_Tag_Relative'] / data['Selected_Tag_Relative'].max()

    # 가중치를 적용하여 종합 점수 계산
    data['Score'] = (
        0.5 * data['Overall_Tag_Normalized'] +
        0.3 * data['Selected_Tag_Absolute_Normalized'] +
        0.2 * data['Selected_Tag_Relative_Normalized']
    )

    # 점수 기준 내림차순 정렬
    ranked_data = data.sort_values(by='Score', ascending=False)

    # 최소 7개 이상의 가게가 나오도록 조정
    if len(ranked_data) < 7:
        print(f"랭킹된 가게가 7개 미만입니다. 현재 {len(ranked_data)}개의 가게가 있습니다.")
    else:
        ranked_data = ranked_data.head(7)  # 상위 7개 가게 선택

    return ranked_data

# 사용자 입력 및 데이터 처리
try:
    # 데이터 선택
    selected_category = get_user_selection_multi(
        "데이터를 선택하세요 (1: 식당, 2: 카페):", ["식당", "카페"]
    )[0]  # 다중 선택 가능하지만 여기서는 첫 번째 선택만 사용

    if selected_category == "식당":
        selected_data = restaurant_data
        # 식당은 음식 종류 선택
        selected_food_category = get_user_selection_multi(
            "음식 종류를 선택하세요:", category_options["식당"]
        )
        print(f"선택된 음식 종류: {', '.join(selected_food_category)}")
        # 필터링: 선택된 음식 종류에 해당하는 데이터만 사용
        filtered_data = selected_data[selected_data['음식종류'].isin(selected_food_category)]
    else:
        selected_data = cafe_data
        filtered_data = selected_data  # 전체 데이터 사용
        selected_food_category = None  # 구분 없음

    # 태그 선택 (다중 선택)
    selected_tags = get_user_selection_multi(
        "중요하게 생각하는 태그를 선택하세요:", list(tag_options[selected_category].keys())
    )
    print(f"선택된 태그들: {', '.join(selected_tags)}")

except KeyError as e:
    print(f"선택지 처리 중 오류가 발생했습니다: {e}")
    raise

# 새로운 랭킹 함수 호출
ranked_results = rank_stores_custom_multi(filtered_data, selected_tags, tag_options[selected_category])

# 필터링된 결과가 없을 경우 모든 음식 종류에 해당하는 식당 반환
if ranked_results.empty:
    print(f"선택한 태그들 '{', '.join(selected_tags)}'에 부합하는 가게가 없습니다. 선택한 음식 종류에 해당하는 모든 가게를 반환합니다.")
    ranked_results = filtered_data

# 결과 출력
if not ranked_results.empty:
    print(f"랭킹된 가게들 (상위 {len(ranked_results)}개):")
    print(ranked_results[['가게명', '음식종류', 'Score']])
else:
    print("선택한 조건에 해당하는 가게가 없습니다.")
# Out:
# 데이터를 선택하세요 (1: 식당, 2: 카페):
# 1. 식당
# 2. 카페
# 선택 번호를 입력하세요 (쉼표로 구분): 1
# 음식 종류를 선택하세요:
# 1. 한식
# 2. 중식
# 3. 일식
# 4. 양식
# 5. 육류
# 6. 아시안음식
# 7. 샐러드
# 선택 번호를 입력하세요 (쉼표로 구분): 1,3,6
# 선택된 음식 종류: 한식, 일식, 아시안음식
# 중요하게 생각하는 태그를 선택하세요:
# 1. 맛
# 2. 특별한 메뉴
# 3. 메뉴 다양성
# 4. 신선도
# 5. 가성비
# 6. 서비스
# 7. 청결
# 8. 혼밥
# 9. 다양한 술
# 10. 분위기
# 11. 대화하기 좋음
# 선택 번호를 입력하세요 (쉼표로 구분): 1
# 선택된 태그들: 맛
# 랭킹된 가게들 (상위 7개):
#          가게명 음식종류     Score
# 65  남산드럼통 본점   한식  0.901025
# 23        더함   한식  0.786159
# 20      숙대소반   한식  0.507262
# 60    철길우동까스   한식  0.486286
# 46    굴다리소곱창   한식  0.479931
# 76     옛날감자전   한식  0.407566
# 22  뜸들이다 숙대점   한식  0.337756
# <ipython-input-3-73b2e80b1781>:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Selected_Tag_Absolute'] = data[selected_phrases].sum(axis=1)
# <ipython-input-3-73b2e80b1781>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Overall_Tag_Count'] = data['태그 총합']
# <ipython-input-3-73b2e80b1781>:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Selected_Tag_Relative'] = data['Selected_Tag_Absolute'] / data['Overall_Tag_Count']
# <ipython-input-3-73b2e80b1781>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Overall_Tag_Normalized'] = data['Overall_Tag_Count'] / data['Overall_Tag_Count'].max()
# <ipython-input-3-73b2e80b1781>:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Selected_Tag_Absolute_Normalized'] = data['Selected_Tag_Absolute'] / data['Selected_Tag_Absolute'].max()
# <ipython-input-3-73b2e80b1781>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Selected_Tag_Relative_Normalized'] = data['Selected_Tag_Relative'] / data['Selected_Tag_Relative'].max()
# <ipython-input-3-73b2e80b1781>:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Score'] = (

# %%
# 상위 태그 컬럼 제외
if selected_category == "식당":
  additional_excluded_columns = [
      "음식이 맛있어요",
      '빵이 맛있어요'
      '특별한 메뉴가 있어요',
      '메뉴 구성이 알차요',
      '재료가 신선해요',
      '잡내가 적어요',
      '고기 질이 좋아요'
      "친절해요",
      "가성비가 좋아요",
      "양이 많아요",
      '반찬이 잘 나와요',
      '음식이 빨리 나와요'
      "매장이 청결해요",
      '화장실이 깨끗해요'
  ]
else :
  additional_excluded_columns = [
      '커피가 맛있어요',
      '디저트가 맛있어요',
      '매장이 청결해요',
      '화장실이 깨끗해요',
      '친절해요',
      '포장이 깔끔해요',
      '아늑해요',
      '인테리어가 멋져요'
    ]

df= ranked_results

  # 첫 두 개 컬럼과 마지막 컬럼 제외
excluded_columns = df.columns[:3].tolist() + df.columns[-2:].tolist()

# 최종 제외 리스트
final_excluded_columns = excluded_columns + additional_excluded_columns

# 나머지 컬럼 리스트
remaining_columns = [col for col in df.columns if col not in final_excluded_columns]
print("Remaining Columns:", remaining_columns)
# Out:
# Remaining Columns: ['혼밥하기 좋아요', '친절해요', '특별한 메뉴가 있어요', '매장이 넓어요', '매장이 청결해요', '인테리어가 멋져요', '특별한 날 가기 좋아요', '단체모임 하기 좋아요', '아늑해요', '음식이 빨리 나와요', '주차하기 편해요', '뷰가 좋아요', '음료가 맛있어요', '아이와 가기 좋아요', '반려동물과 가기 좋아요', '룸이 잘 되어있어요', '오래 머무르기 좋아요', '환기가 잘 돼요', '차분한 분위기에요', '코스요리가 알차요', '비싼 만큼 가치있어요', '대화하기 좋아요', '건강한 맛이에요', '음악이 좋아요', '좌석이 편해요', '사진이 잘 나와요', '현지 맛에 가까워요', '고기 질이 좋아요', '샐러드바가 잘 되어있어요', '혼술하기 좋아요', '향신료가 강하지 않아요', '야외공간이 멋져요', '컨셉이 독특해요', '포장이 깔끔해요', '술이 다양해요', '직접 잘 구워줘요', '커피가 맛있어요', '디저트가 맛있어요', '기본 안주가 좋아요', '집중하기 좋아요', '빵이 맛있어요', '태그 총합', 'Selected_Tag_Absolute', 'Overall_Tag_Count', 'Selected_Tag_Relative', 'Overall_Tag_Normalized', 'Selected_Tag_Absolute_Normalized']

# %%
# Input 텍스트와 Remaining Columns 정의
input_txt = [input("기타 입력 사항을 입력하시오: ")]
# Out:
# 기타 입력 사항을 입력하시오: 든든한 밥 메뉴

# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.metrics.pairwise import cosine_similarity

# KoBERT 모델 및 토크나이저 로드
model_name = "monologg/kobert"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# The repository for monologg/kobert contains custom code which must be executed to correctly load the model. You can inspect the repository content at https://hf.co/monologg/kobert.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y

# %%
# 문장 임베딩 생성 함수
def get_embeddings(text_list):
    inputs = tokenizer(text_list, return_tensors="pt", padding=True, truncation=True, max_length=64)
    with torch.no_grad():
        outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.mean(dim=1)  # 평균 풀링 사용
    return embeddings

# Threshold 설정
threshold = 0.72

# Input 텍스트와 Remaining Columns 임베딩
input_embeddings = get_embeddings(input_txt)
remaining_embeddings = get_embeddings(remaining_columns)

# 유사도 계산
similarity_matrix = cosine_similarity(input_embeddings.numpy(), remaining_embeddings.numpy())

# 유사도 결과를 데이터프레임으로 변환
similarity_df2 = pd.DataFrame(
    similarity_matrix,
    index=input_txt,
    columns=remaining_columns
)

# high_similarity_pairs 구성 및 결과 저장
high_similarity_pairs = []
result_data = []

for input_text in similarity_df2.index:
    similar_columns = similarity_df2.loc[input_text][similarity_df2.loc[input_text] >= threshold]

    # 상위 5개 선택 (유사도 기준 내림차순)
    selected_tags = similar_columns.sort_values(ascending=False).head(5)

    # 선택된 태그가 있다면 리스트로 저장, 없다면 빈 리스트
    if len(selected_tags) > 0:
        tag_list = selected_tags.index.tolist()
    else:
        tag_list = []

    # high_similarity_pairs에 추가
    for column, similarity in selected_tags.items():
        high_similarity_pairs.append((input_text, column, similarity))

    # 결과 데이터 구성
    result_data.append({"입력 텍스트": input_text, "최종 선택 태그의 리스트": tag_list})

# 결과 데이터프레임 생성
result_df = pd.DataFrame(result_data)

# 출력
print(result_df)
# Out:
#      입력 텍스트 최종 선택 태그의 리스트
# 0  든든한 밥 메뉴            []

# %%
# 디버깅: result_df의 컬럼 확인
print("result_df 컬럼들:", result_df.columns)

# 각 input_txt에 대해 조건을 만족하는 가게별 유사도 점수 계산
final_results = []

for input_text in result_df["입력 텍스트"]:
    # 디버깅: 입력 텍스트 확인
    print(f"현재 처리 중: {input_text}")

    # 해당 input_txt의 tag_list 가져오기
    if "최종 선택 태그의 리스트" not in result_df.columns:
        raise KeyError("'최종 선택 태그의 리스트' 컬럼이 존재하지 않습니다. result_df 컬럼들을 확인하세요.")

    tag_list = result_df[result_df["입력 텍스트"] == input_text]["최종 선택 태그의 리스트"].values[0]

    # tag_list가 비어 있는 경우 처리
    if len(tag_list) == 0:
        final_results.append({
            "입력 텍스트": input_text,
            "추천 가게": [],
        })
        continue

    # 태그 수의 비율 계산 (1 / len(tag_list) * 태그 수)
    df["태그 비율"] = df[tag_list].sum(axis=1) / len(tag_list)

    # 조건에 맞는 가게 필터링 (태그 수 >= len(tag_list))
    filtered_df = df[df[tag_list].gt(0).sum(axis=1) >= len(tag_list)]

    # 태그 비율 기준 내림차순 정렬 후 상위 10개 가게 추출
    top_stores = filtered_df.sort_values("태그 비율", ascending=False).head(10)

    # 결과 저장
    recommended_stores = [
        {"가게명": row["가게명"], "유사도 점수": row["태그 비율"]}
        for _, row in top_stores.iterrows()
    ]

    final_results.append({
        "입력 텍스트": input_text,
        "추천 가게": recommended_stores,
    })

# 최종 결과 출력
for result2 in final_results:
    print(f"입력 텍스트: {result2['입력 텍스트']}")
    print("추천 가게:")
    for store in result2["추천 가게"]:
        print(f" - 가게명: {store['가게명']}, 유사도 점수: {store['유사도 점수']:.4f}")
    print()
# Out:
# result_df 컬럼들: Index(['입력 텍스트', '최종 선택 태그의 리스트'], dtype='object')
# 현재 처리 중: 든든한 밥 메뉴
# 입력 텍스트: 든든한 밥 메뉴
# 추천 가게:

# %% [markdown]
# # TF - IDF 리뷰 유사도 추출

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

input_txt =['든든한 밥 메뉴']

if selected_category == "식당":
    df_t= pd.read_csv('/content/drive/MyDrive/content/result_meal.csv')
else:
    df_t= pd.read_csv('/content/drive/MyDrive/content/result_cafe.csv')

# 가게명이 포함된 리스트가 ranked_results['가게명']에 있다고 가정
ranked_store_names = ranked_results['가게명']

# df_t에서 store_name이 ranked_store_names에 존재하는 경우만 필터링
df_t = df_t[df_t['store_name'].isin(ranked_store_names)]

# NaN 값 제거 또는 대체
df_t["text_review"] = df_t["text_review"].fillna("")  # NaN 값을 빈 문자열로 대체

# TF-IDF 벡터라이저 초기화
tfidf_vectorizer = TfidfVectorizer()

# 데이터셋 리뷰 벡터화
corpus = df_t["text_review"].tolist()
tfidf_matrix = tfidf_vectorizer.fit_transform(corpus)

# 결과 저장을 위한 리스트
result_data = []

# 각 입력 텍스트에 대해 유사도 계산
for user_input in input_txt:
    # 입력 텍스트 벡터화
    input_vector = tfidf_vectorizer.transform([user_input])

    # 코사인 유사도 계산
    similarity_scores = cosine_similarity(input_vector, tfidf_matrix)

    # 유사도 추가
    df_t["Similarity"] = similarity_scores.flatten()

    # 장소별 유사도 상위 5개의 점수 평균 계산
    top5_avg_similarity = (
        df_t.groupby("store_name")
        .apply(lambda group: group.nlargest(10, "Similarity")["Similarity"].mean())
        .reset_index(name="Avg_Similarity")
    )

    # 평균 유사도를 기준으로 상위 5개의 장소
    top5_places = top5_avg_similarity.sort_values(by="Avg_Similarity", ascending=False).head(10)

    # 결과 저장
    result_data.append({"입력 텍스트": user_input, "상위 5개 장소 및 평균 유사도": top5_places.to_dict(orient="records")})

# 결과 데이터프레임 생성
result_df_2 = pd.DataFrame(result_data)

# 출력
print(result_df_2)
# Out:
#      입력 텍스트                                  상위 5개 장소 및 평균 유사도
# 0  든든한 밥 메뉴  [{'store_name': '더함', 'Avg_Similarity': 0.0263...
# <ipython-input-9-6ea4e98a5dbd>:45: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda group: group.nlargest(10, "Similarity")["Similarity"].mean())

# %%
# 유사도 점수가 높은 10개의 가게 선정 및 차등 가중치 적용
final_results = []

# 각 입력 텍스트에 대해 상위 10개 가게 선정 및 점수 계산
for result in result_data:
    user_input = result["입력 텍스트"]
    top_places = pd.DataFrame(result["상위 5개 장소 및 평균 유사도"])

    # 동일한 가게가 여러 입력 텍스트에 등장할 수 있으므로 모든 결과 합치기
    if not top_places.empty:
        # 상위 10개의 가게 및 평균 유사도 추출
        sorted_places = top_places.sort_values("Avg_Similarity", ascending=False).head(10)

        # 차등 가중치 계산: 10~5에서 0.5씩 감소
        weights = [100 - i * 5 for i in range(len(sorted_places))]

        # 최종 점수 계산: 유사도 × 가중치
        sorted_places["Weighted_Score"] = sorted_places["Avg_Similarity"] * weights

        # 최종 점수 기준으로 정렬
        sorted_places = sorted_places.sort_values("Weighted_Score", ascending=False)

        # 결과 저장
        final_results.append({
            "입력 텍스트": user_input,
            "추천 가게": sorted_places[["store_name", "Weighted_Score"]].to_dict(orient="records")
        })

# 최종 결과 출력
for result in final_results:
    print(f"입력 텍스트: {result['입력 텍스트']}")
    print("추천 가게:")
    for store in result["추천 가게"]:
        print(f" - 가게명: {store['store_name']}, 점수: {store['Weighted_Score']:.2f}")
    print()
# Out:
# 입력 텍스트: 든든한 밥 메뉴
# 추천 가게:
#  - 가게명: 더함, 점수: 2.64
#  - 가게명: 숙대소반, 점수: 2.29
#  - 가게명: 옛날감자전, 점수: 0.71
#  - 가게명: 뜸들이다 숙대점, 점수: 0.49
#  - 가게명: 굴다리소곱창, 점수: 0.00
#  - 가게명: 남산드럼통 본점, 점수: 0.00
#  - 가게명: 철길우동까스, 점수: 0.00

# %%
# 입력 텍스트별 최종 유사도 점수 계산
final_results_by_input = {}

# result와 result2의 점수 합산
for result, result2 in zip(final_results, final_results):
    input_text = result["입력 텍스트"]

    # 입력 텍스트에 대한 각 가게의 점수 합산
    store_scores = {}

    # result에서 점수 합산
    for store in result["추천 가게"]:
        store_name = store.get("store_name", store.get("가게명"))
        score = store.get("유사도 점수", store.get("Weighted_Score"))
        if store_name and score:
            if store_name not in store_scores:
                store_scores[store_name] = 0
            store_scores[store_name] += score

    # result2에서 점수 합산
    for store in result2["추천 가게"]:
        store_name = store.get("store_name", store.get("가게명"))
        score = store.get("유사도 점수", store.get("Weighted_Score"))
        if store_name and score:
            if store_name not in store_scores:
                store_scores[store_name] = 0
            store_scores[store_name] += score

    # 입력 텍스트별로 상위 5곳 추출
    sorted_stores = sorted(store_scores.items(), key=lambda x: x[1], reverse=True)[:5]
    final_results_by_input[input_text] = sorted_stores

# 결과 출력
for input_text, top_stores in final_results_by_input.items():
    print(f"입력 텍스트: {input_text}")
    print("최종 유사도 점수 상위 5곳:")
    for store_name, score in top_stores:
        print(f" - 가게명: {store_name}, 최종 점수: {score:.4f}")
    print()
# Out:
# 입력 텍스트: 든든한 밥 메뉴
# 최종 유사도 점수 상위 5곳:
#  - 가게명: 더함, 최종 점수: 5.2790
#  - 가게명: 숙대소반, 최종 점수: 4.5816
#  - 가게명: 옛날감자전, 최종 점수: 1.4278
#  - 가게명: 뜸들이다 숙대점, 최종 점수: 0.9793

# %% [markdown]
# # 사용자 입력 기반 추천 최종 점수

# %%
# 입력 텍스트별로 전체 점수 추출
sorted_stores_all = sorted(store_scores.items(), key=lambda x: x[1], reverse=True)[:]
final_results_by_input[input_text] = sorted_stores_all
print(final_results_by_input[input_text])
# Out:
# [('더함', 5.279029557735614), ('숙대소반', 4.581607702968833), ('옛날감자전', 1.427783982136996), ('뜸들이다 숙대점', 0.9793121711169293)]

# %% [markdown]
# # 사용자 리뷰 기반 추천

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.impute import SimpleImputer

# %%
global user_store_scores

def load_and_preprocess(file_path_user, file_paths_restaurant):

    user_data = pd.read_csv(file_path_user)
    restaurant_data = pd.read_csv(file_paths_restaurant)

    # 사용자와 식당의 ID 추출
    user_ids = user_data['nickname'].tolist()
    restaurant_ids = restaurant_data['\uac00\uac8c\uba85'].tolist()

    # 숫자형 데이터 추출
    user_data_numeric = user_data.select_dtypes(include=['float64', 'int64'])
    restaurant_data_numeric = restaurant_data.select_dtypes(include=['float64', 'int64'])

    # 결측치 처리
    imputer = SimpleImputer(strategy='mean')
    user_data_imputed = imputer.fit_transform(user_data_numeric)
    restaurant_data_imputed = imputer.fit_transform(restaurant_data_numeric)

    # 비율 계산 (빈도수를 전체 합으로 나눔)
    restaurant_data_proportions = restaurant_data_imputed / restaurant_data_imputed.sum(axis=1, keepdims=True)

    # 정규화
    scaler = StandardScaler()
    user_data_scaled = scaler.fit_transform(user_data_imputed)
    restaurant_data_scaled = scaler.fit_transform(restaurant_data_proportions)

    return user_data_scaled, restaurant_data_scaled, user_ids, restaurant_ids, restaurant_data

def perform_pca(data, n_components=3):

    pca = PCA(n_components=n_components)
    return pca.fit_transform(data)

def calculate_recommendation_scores(user_features, restaurant_features, weights=None):

    if weights is not None:
        # 가중치 적용
        weights = np.array(weights)
        restaurant_features = restaurant_features * weights
    return cosine_similarity(user_features, restaurant_features)

def generate_recommendations(scores, user_ids, restaurant_ids, top_n=5):

    recommendations = []
    global user_store_scores
    user_store_scores = {}

    for i, user_id in enumerate(user_ids):
        top_indices = scores[i].argsort()[::-1][:top_n]
        top_restaurants = [restaurant_ids[j] for j in top_indices]
        top_scores = [scores[i][j] for j in top_indices]
        recommendations.append({"user_id": user_id, "recommended_restaurants": top_restaurants, "scores": top_scores})

        # 사용자별 점수 저장
        user_store_scores[user_id] = list(zip(top_restaurants, top_scores))

    return pd.DataFrame(recommendations)

def print_recommendations(recommendations):

    for _, row in recommendations.iterrows():
        print(f"User ID: {row['user_id']}")
        print("Recommended Restaurants and Scores:")
        for restaurant, score in zip(row['recommended_restaurants'], row['scores']):
            print(f"  - {restaurant}: {score:.4f}")
        print()

def main(file_path_user, file_paths_restaurant, n_components=3, top_n=5):

    # 데이터 로드 및 전처리
    user_data, restaurant_data, user_ids, restaurant_ids, raw_restaurant_data = load_and_preprocess(
        file_path_user, file_paths_restaurant
    )

    # PCA 수행
    user_features = perform_pca(user_data, n_components)
    restaurant_features = perform_pca(restaurant_data, n_components)

    # 유사도 계산
    scores = calculate_recommendation_scores(user_features, restaurant_features)

    # 추천 결과 생성 및 출력
    recommendations = generate_recommendations(scores, user_ids, restaurant_ids, top_n)
    print_recommendations(recommendations)

    # user_store_scores 반환
    return user_store_scores

# 실행
user_file_path = "/content/drive/MyDrive/content/dacos_tagging_adjusted_sorted.csv"
restaurant_file_paths = "/content/drive/MyDrive/content/combined_restaurant_data.csv"
user_store_scores = main(user_file_path, restaurant_file_paths, n_components=3, top_n=5)
# Out:
# User ID: 369369z
# Recommended Restaurants and Scores:
#   - MUJABEE: 0.9858
#   - Jesus Coffee: 0.9634
#   - 때가이르매: 0.9497
#   - 미드스트오브플로우: 0.9413
#   - 와플하우스: 0.9389
#
# User ID: A8뜨뚜
# Recommended Restaurants and Scores:
#   - 카페 퓨엔테: 0.9918
#   - 와플하우스: 0.9861
#   - 위드달걀빵: 0.9730
#   - 스택빈 숙대점: 0.9532
#   - 스타벅스 숙대점: 0.9420
#
# User ID: Chiabata
# Recommended Restaurants and Scores:
#   - 미스터카츠 숙대입구점: 0.9989
#   - 샤브로21 숙명여대: 0.9804
#   - 나폴리키친: 0.9655
#   - 네코노스시: 0.9603
#   - 베스트프렌드: 0.9465
#
# User ID: DEJAVU
# Recommended Restaurants and Scores:
#   - 카페나리나무: 0.9940
#   - 컴포즈커피 숙명여대점: 0.9626
#   - 루다브레드: 0.9092
#   - 이웃집영준이: 0.8776
#   - 평화남영: 0.8761
#
# User ID: FromA
# Recommended Restaurants and Scores:
#   - 키보 에다마메: 0.9750
#   - 벤티프레소 숙명여대점: 0.9706
#   - 루다브레드: 0.9630
#   - 없음 베이커리: 0.9466
#   - 꽃보다크레페: 0.9435
#
# User ID: Junns
# Recommended Restaurants and Scores:
#   - 마시앤바시: 0.8797
#   - 사이공마켓 숙대점: 0.7937
#   - 리또리또 숙대점: 0.6793
#   - 포36거리 숙대점: 0.6096
#   - 아리랑노점 숙대점: 0.6048
#
# User ID: Reenfldos
# Recommended Restaurants and Scores:
#   - 스택빈 숙대점: 0.9144
#   - 스타벅스 숙대점: 0.9056
#   - 킷테: 0.8608
#   - 카페 퓨엔테: 0.8317
#   - 마시앤바시: 0.8314
#
# User ID: iamimmm
# Recommended Restaurants and Scores:
#   - 샐러디 숙명여대점: 0.9799
#   - 이자와 숙대점: 0.9652
#   - 포라임 숙대본점: 0.9401
#   - 비일: 0.9291
#   - 더함: 0.9149
#
# User ID: lune93
# Recommended Restaurants and Scores:
#   - 카페나리나무: 0.9373
#   - 컴포즈커피 숙명여대점: 0.9069
#   - 앙꼬: 0.9019
#   - 위드달걀빵: 0.8839
#   - 쥬케로카페 숙대점: 0.8706
#
# User ID: ric****
# Recommended Restaurants and Scores:
#   - 없음 베이커리: 0.9625
#   - 꽃보다크레페: 0.9536
#   - 키보 에다마메: 0.9312
#   - 경성빵공장 카스테라점: 0.9262
#   - 라이언스커피로스터스: 0.9173
#
# User ID: u07****
# Recommended Restaurants and Scores:
#   - 앙꼬: 0.8924
#   - 카페나리나무: 0.8910
#   - 가든한밤: 0.8725
#   - 쥬케로카페 숙대점: 0.8697
#   - 컴포즈커피 숙명여대점: 0.8355
#
# User ID: whrhwhdoo
# Recommended Restaurants and Scores:
#   - 메이드바이그레이스: 0.9677
#   - 때가이르매: 0.8953
#   - 미드스트오브플로우: 0.8779
#   - 먼데이피크닉: 0.8630
#   - 틸데: 0.8514
#
# User ID: 김니00
# Recommended Restaurants and Scores:
#   - 마시앤바시: 0.9729
#   - 킷테: 0.8972
#   - 스타벅스 숙대점: 0.7192
#   - 스택빈 숙대점: 0.7136
#   - 쥬케로카페 숙대점: 0.6272
#
# User ID: 꿀맥주
# Recommended Restaurants and Scores:
#   - MUJABEE: 0.9589
#   - 와플하우스: 0.9511
#   - 틸데: 0.9260
#   - Jesus Coffee: 0.9258
#   - 카페 퓨엔테: 0.9232
#
# User ID: 대동맛지도
# Recommended Restaurants and Scores:
#   - 틸데: 0.9779
#   - 때가이르매: 0.9710
#   - 미드스트오브플로우: 0.9276
#   - Jesus Coffee: 0.9176
#   - MUJABEE: 0.9066
#
# User ID: 데세헤
# Recommended Restaurants and Scores:
#   - 장재근초밥: 0.9967
#   - 면식당 숙명여대점: 0.9901
#   - 더함: 0.9887
#   - 포라임 숙대본점: 0.9766
#   - 베나레스 숙대점: 0.9430
#
# User ID: 도도는뚀
# Recommended Restaurants and Scores:
#   - 미드스트오브플로우: 0.9970
#   - Jesus Coffee: 0.9900
#   - 먼데이피크닉: 0.9856
#   - 경성빵공장 카스테라점: 0.9737
#   - 때가이르매: 0.9736
#
# User ID: 돌고래삼촌
# Recommended Restaurants and Scores:
#   - 구복만두: 0.9986
#   - 품계: 0.9983
#   - 멘타미: 0.9933
#   - 카페시바: 0.9868
#   - 오복함흥냉면: 0.9859
#
# User ID: 딸기4282
# Recommended Restaurants and Scores:
#   - 킷테: 0.9673
#   - 스타벅스 숙대점: 0.8905
#   - 스택빈 숙대점: 0.8859
#   - 마시앤바시: 0.8813
#   - 쥬케로카페 숙대점: 0.8258
#
# User ID: 뚝딱64
# Recommended Restaurants and Scores:
#   - 마시앤바시: 0.9633
#   - 사이공마켓 숙대점: 0.6320
#   - 킷테: 0.6156
#   - 리또리또 숙대점: 0.5480
#   - 멘타미: 0.5450
#
# User ID: 리나4891
# Recommended Restaurants and Scores:
#   - 장재근초밥: 0.9986
#   - 더함: 0.9905
#   - 포라임 숙대본점: 0.9801
#   - 면식당 숙명여대점: 0.9714
#   - 샤브로21 숙명여대: 0.9532
#
# User ID: 리뷰꾸르잼
# Recommended Restaurants and Scores:
#   - 리또리또 숙대점: 0.9876
#   - 포36거리 숙대점: 0.9754
#   - 아리랑노점 숙대점: 0.9716
#   - 츄르츄르라멘: 0.9705
#   - 까치네분식: 0.9704
#
# User ID: 맛이써
# Recommended Restaurants and Scores:
#   - 김밥2000: 0.9943
#   - 두리식당: 0.9940
#   - 대관령목장: 0.9915
#   - 구구: 0.9843
#   - 굴다리소곱창: 0.9830
#
# User ID: 맛있는거는 못참아
# Recommended Restaurants and Scores:
#   - 메이드바이그레이스: 0.9374
#   - 남영동양문 본점: 0.9198
#   - 상록수: 0.9133
#   - 하이퐁가든: 0.9022
#   - 청기와타운 남영점: 0.8543
#
# User ID: 밍닝몽
# Recommended Restaurants and Scores:
#   - 마시앤바시: 0.9821
#   - 킷테: 0.6398
#   - 다이빙룸: 0.5993
#   - 레이브피자: 0.5953
#   - 멘타미: 0.5292
#
# User ID: 밤 새 피어난 비
# Recommended Restaurants and Scores:
#   - 마시앤바시: 0.8960
#   - 다이빙룸: 0.7906
#   - 레이브피자: 0.7660
#   - 틸데: 0.6953
#   - 남영탉: 0.6352
#
# User ID: 봄 나무
# Recommended Restaurants and Scores:
#   - 장재근초밥: 0.9982
#   - 더함: 0.9891
#   - 포라임 숙대본점: 0.9779
#   - 면식당 숙명여대점: 0.9725
#   - 샤브로21 숙명여대: 0.9526
#
# User ID: 봄여름가을겨울그리고여름
# Recommended Restaurants and Scores:
#   - 홍곱창 숙명여대점: 0.9237
#   - 하이퐁가든: 0.7412
#   - 없음 베이커리: 0.6911
#   - 솔티드 스모크: 0.6689
#   - 타코비 숙명여대점: 0.6515
#
# User ID: 빼코빼코
# Recommended Restaurants and Scores:
#   - 와플하우스: 0.9808
#   - 카페 퓨엔테: 0.9617
#   - 위드달걀빵: 0.9535
#   - MUJABEE: 0.9315
#   - 스택빈 숙대점: 0.8959
#
# User ID: 사랑스런백괘
# Recommended Restaurants and Scores:
#   - 키보 에다마메: 0.9773
#   - 벤티프레소 숙명여대점: 0.9693
#   - 루다브레드: 0.9608
#   - 없음 베이커리: 0.9500
#   - 꽃보다크레페: 0.9460
#
# User ID: 삼의미학
# Recommended Restaurants and Scores:
#   - 미스터카츠 숙대입구점: 0.9075
#   - 샤브로21 숙명여대: 0.8724
#   - 나폴리키친: 0.7970
#   - 킷테: 0.7913
#   - 네코노스시: 0.7836
#
# User ID: 새댁528
# Recommended Restaurants and Scores:
#   - 컴포즈커피 숙명여대점: 0.9833
#   - 와플하우스: 0.9595
#   - 위드달걀빵: 0.9540
#   - 카페 퓨엔테: 0.8962
#   - MUJABEE: 0.8943
#
# User ID: 샐연
# Recommended Restaurants and Scores:
#   - 컴포즈커피 숙명여대점: 0.9539
#   - 카페나리나무: 0.9407
#   - 위드달걀빵: 0.9354
#   - 앙꼬: 0.9226
#   - 와플하우스: 0.8934
#
# User ID: 섹쉬올리브
# Recommended Restaurants and Scores:
#   - 카페나리나무: 0.9949
#   - 컴포즈커피 숙명여대점: 0.9528
#   - 루다브레드: 0.8971
#   - 가든한밤: 0.8892
#   - 이웃집영준이: 0.8871
#
# User ID: 솔직담백 솔담씨의 리뷰스토리
# Recommended Restaurants and Scores:
#   - 솔티드 스모크: 0.9868
#   - 별진화로구이: 0.9767
#   - 하이퐁가든: 0.9680
#   - 윤지식당: 0.9666
#   - 구구: 0.9382
#
# User ID: 순진한깜박
# Recommended Restaurants and Scores:
#   - 면식당 숙명여대점: 0.9489
#   - 베나레스 숙대점: 0.9448
#   - 탄막: 0.9280
#   - 가든한밤: 0.9262
#   - 장재근초밥: 0.9184
#
# User ID: 스마일엘라
# Recommended Restaurants and Scores:
#   - 몬스터플레이스: 0.9521
#   - 타코비 숙명여대점: 0.9087
#   - 홍곱창 숙명여대점: 0.8718
#   - 마포구이마당 숙대직영점: 0.8686
#   - 소소라면 닭꼬치: 0.7103
#
# User ID: 아보펭펭
# Recommended Restaurants and Scores:
#   - 홍곱창 숙명여대점: 0.9569
#   - 하이퐁가든: 0.9073
#   - 솔티드 스모크: 0.8744
#   - 별진화로구이: 0.8345
#   - 윤지식당: 0.8162
#
# User ID: 아암마시따
# Recommended Restaurants and Scores:
#   - 온센 용산구점: 0.8678
#   - 멘타미: 0.8662
#   - 까치네분식: 0.8578
#   - 츄르츄르라멘: 0.8572
#   - 포36거리 숙대점: 0.8563
#
# User ID: 얄롱히
# Recommended Restaurants and Scores:
#   - 미스터카츠 숙대입구점: 0.9906
#   - 샤브로21 숙명여대: 0.9663
#   - 나폴리키친: 0.9374
#   - 네코노스시: 0.9309
#   - 베스트프렌드: 0.9128
#
# User ID: 연마백
# Recommended Restaurants and Scores:
#   - 면식당 숙명여대점: 0.9873
#   - 베나레스 숙대점: 0.9793
#   - 장재근초밥: 0.9561
#   - 소소라면 닭꼬치: 0.9551
#   - 더함: 0.9364
#
# User ID: 잡덕수집가
# Recommended Restaurants and Scores:
#   - MUJABEE: 0.9760
#   - Jesus Coffee: 0.9588
#   - 와플하우스: 0.9422
#   - 미드스트오브플로우: 0.9365
#   - 때가이르매: 0.9132
#
# User ID: 전국적인 먹짱
# Recommended Restaurants and Scores:
#   - 몬스터플레이스: 0.9663
#   - 소소라면 닭꼬치: 0.9579
#   - 면식당 숙명여대점: 0.9452
#   - 베나레스 숙대점: 0.9441
#   - 포라임 숙대본점: 0.9263
#
# User ID: 지민5717
# Recommended Restaurants and Scores:
#   - 사이공마켓 숙대점: 0.9618
#   - 리또리또 숙대점: 0.6970
#   - 긴자료코 숙대점: 0.6922
#   - 달볶이: 0.6920
#   - 마시앤바시: 0.6867
#
# User ID: 차차는
# Recommended Restaurants and Scores:
#   - 마포구이마당 숙대직영점: 0.9971
#   - 타코비 숙명여대점: 0.9570
#   - 샐러디 숙명여대점: 0.9002
#   - 육쌈냉면 숙대점: 0.8855
#   - 홍짜장 숙대점: 0.8697
#
# User ID: 쿨제이95
# Recommended Restaurants and Scores:
#   - 평화남영: 0.9877
#   - 루다브레드: 0.9666
#   - 카페나리나무: 0.9658
#   - 벤티프레소 숙명여대점: 0.9612
#   - 이웃집영준이: 0.9408
#
# User ID: 푸딩쓰
# Recommended Restaurants and Scores:
#   - 남영동양문 본점: 0.9644
#   - 메이드바이그레이스: 0.9542
#   - 상록수: 0.9532
#   - 짚신매운갈비찜 숙대점: 0.8886
#   - 쌍대포소금구이 본점: 0.8731
#
# User ID: 화초까지먹을기세
# Recommended Restaurants and Scores:
#   - 라이언스커피로스터스: 0.9555
#   - 키보 에다마메: 0.9526
#   - 루다브레드: 0.9478
#   - 벤티프레소 숙명여대점: 0.9453
#   - 경성빵공장 카스테라점: 0.9450
#
# User ID: 황도0809
# Recommended Restaurants and Scores:
#   - 사이공마켓 숙대점: 0.8879
#   - 마시앤바시: 0.7998
#   - 리또리또 숙대점: 0.7086
#   - 달볶이: 0.6548
#   - 긴자료코 숙대점: 0.6512
#
# User ID: 후암동 올리
# Recommended Restaurants and Scores:
#   - 타코비 숙명여대점: 0.9788
#   - 홍곱창 숙명여대점: 0.9187
#   - 홍짜장 숙대점: 0.9013
#   - 마포구이마당 숙대직영점: 0.8898
#   - 별진화로구이: 0.8877
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['index' '가게명']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
global user_store_scores

def load_and_preprocess(file_path_user, file_paths_restaurant):

    user_data = pd.read_csv(file_path_user)
    restaurant_data = pd.read_csv(file_paths_restaurant)

    # 사용자와 식당의 ID 추출
    user_ids = user_data['nickname'].tolist()
    restaurant_ids = restaurant_data['\uac00\uac8c\uba85'].tolist()

    # 숫자형 데이터 추출
    user_data_numeric = user_data.select_dtypes(include=['float64', 'int64'])
    restaurant_data_numeric = restaurant_data.select_dtypes(include=['float64', 'int64'])

    # 결측치 처리
    imputer = SimpleImputer(strategy='mean')
    user_data_imputed = imputer.fit_transform(user_data_numeric)
    restaurant_data_imputed = imputer.fit_transform(restaurant_data_numeric)

    # 비율 계산 (빈도수를 전체 합으로 나눔)
    restaurant_data_proportions = restaurant_data_imputed / restaurant_data_imputed.sum(axis=1, keepdims=True)

    # 정규화
    scaler = StandardScaler()
    user_data_scaled = scaler.fit_transform(user_data_imputed)
    restaurant_data_scaled = scaler.fit_transform(restaurant_data_proportions)

    return user_data_scaled, restaurant_data_scaled, user_ids, restaurant_ids, restaurant_data

def perform_pca(data, n_components=3):

    pca = PCA(n_components=n_components)
    return pca.fit_transform(data)

def calculate_recommendation_scores(user_features, restaurant_features, weights=None):

    if weights is not None:
        # 가중치 적용
        weights = np.array(weights)
        restaurant_features = restaurant_features * weights
    return cosine_similarity(user_features, restaurant_features)

def generate_recommendations(scores, user_ids, restaurant_ids):

    recommendations = []
    global user_store_scores
    user_store_scores = {}

    for i, user_id in enumerate(user_ids):
        # 모든 레스토랑과의 점수 계산
        all_restaurants = [restaurant_ids[j] for j in range(len(restaurant_ids))]
        all_scores = [scores[i][j] for j in range(len(restaurant_ids))]

        recommendations.append({"user_id": user_id, "recommended_restaurants": all_restaurants, "scores": all_scores})

        # 사용자별 점수 저장
        user_store_scores[user_id] = list(zip(all_restaurants, all_scores))

    return pd.DataFrame(recommendations)

def print_recommendations(recommendations):

    for _, row in recommendations.iterrows():
        print(f"User ID: {row['user_id']}")
        print("Recommended Restaurants and Scores:")
        for restaurant, score in zip(row['recommended_restaurants'], row['scores']):
            print(f"  - {restaurant}: {score:.4f}")
        print()

def main(file_path_user, file_paths_restaurant, n_components=3):

    # 데이터 로드 및 전처리
    user_data, restaurant_data, user_ids, restaurant_ids, raw_restaurant_data = load_and_preprocess(
        file_path_user, file_paths_restaurant
    )

    # PCA 수행
    user_features = perform_pca(user_data, n_components)
    restaurant_features = perform_pca(restaurant_data, n_components)

    # 유사도 계산
    scores = calculate_recommendation_scores(user_features, restaurant_features)

    # 추천 결과 생성 및 출력
    recommendations = generate_recommendations(scores, user_ids, restaurant_ids)
    print_recommendations(recommendations)

    # user_store_scores 반환
    return user_store_scores

# 실행
user_file_path = "/content/drive/MyDrive/content/dacos_tagging_adjusted_sorted.csv"
restaurant_file_paths = "/content/drive/MyDrive/content/combined_restaurant_data.csv"
user_store_scores = main(user_file_path, restaurant_file_paths, n_components=3)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['index' '가게명']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   - 정: -0.5636
#   - 지지고 숙명여대점: -0.5519
#   - 이삭토스트 숙명여대점: -0.5473
#   - 리또리또 숙대점: -0.2574
#   - 미스터카츠 숙대입구점: -0.0185
#   - 하마: -0.5394
#   - 숙대소반: -0.5471
#   - 부암동치킨: -0.4813
#   - 뜸들이다 숙대점: -0.3245
#   - 더함: -0.4577
#   - 홍짜장 숙대점: -0.7553
#   - 무모한초밥 숙명여대점: -0.3267
#   - 마시앤바시: 0.8314
#   - 긴자료코 숙대점: -0.4371
#   - 홍곱창 숙명여대점: -0.9330
#   - 이자와 숙대점: -0.5019
#   - 타코비 숙명여대점: -0.9818
#   - 비일: -0.4049
#   - 베나레스 숙대점: -0.4368
#   - 샤브로21 숙명여대: -0.1311
#   - 나폴리키친: -0.2399
#   - 어바웃샤브 숙명여대점: -0.5697
#   - 백채김치찌개 숙대입구점: -0.4529
#   - 본죽&비빔밥cafe 숙대입구역점: -0.3370
#   - 만나칼국수: -0.4610
#   - 교촌치킨 숙대점: -0.4986
#   - 까치네분식: -0.2358
#   - 메이드바이그레이스: 0.1413
#   - 버거인: -0.2517
#   - 츄르츄르라멘: -0.2375
#   - 레이브피자: 0.2802
#   - 김밥2000: -0.5971
#   - 굴다리소곱창: -0.3638
#   - 두리식당: -0.6022
#   - 한입소반: -0.3578
#   - 써브웨이 숙명여대점: 0.6584
#   - 별진화로구이: 0.8877
#   - 남영동양문 본점: 0.2194
#   - 원동미나리삼겹살: 0.5250
#   - 다이빙룸: -0.0613
#   - KFC 숙대입구점: 0.5940
#   - 하노이별 숙대입구점: 0.6725
#   - 철길우동까스: 0.6827
#   - 대관령목장: 0.7914
#   - 구복만두: 0.3993
#   - 한강로칼국수: 0.6119
#   - 솔티드 스모크: 0.8024
#   - 남산드럼통 본점: 0.6331
#   - 둘이파전: 0.7071
#   - 짚신매운갈비찜 숙대점: 0.3886
#   - 멘타미: 0.3446
#   - 청기와타운 남영점: 0.5867
#   - 오복함흥냉면: 0.4541
#   - 카페시바: 0.3622
#   - 하이퐁가든: 0.7266
#   - 품계: 0.3882
#   - 온센 용산구점: 0.4578
#   - 구구: 0.7458
#   - 옛날감자전: 0.5607
#   - 윤지식당: 0.7724
#   - 살팀보카: 0.3492
#   - 남영탉: 0.2177
#   - 키보 에다마메: -0.1068
#   - 이웃집영준이: -0.1186
#   - 모토카레시: -0.1227
#   - 더블랙웨일바: -0.1323
#   - 가든한밤: -0.2521
#   - 탄막: -0.1398
#   - 평화남영: -0.1132
#   - 소소라면 닭꼬치: 0.2278
#   - 앙꼬: -0.9356
#   - 루다브레드: -0.3244
#   - 컴포즈커피 숙명여대점: -0.6583
#   - 벤티프레소 숙명여대점: -0.2455
#   - 위드달걀빵: -0.8739
#   - 쥬케로카페 숙대점: -0.9569
#   - 몬스터플레이스: 0.6591
#   - 킷테: -0.9053
#   - 카페 퓨엔테: -0.9441
#   - 카페나리나무: -0.4597
#   - 스타벅스 숙대점: -0.9916
#   - 스택빈 숙대점: -0.9936
#   - 와플하우스: -0.8728
#   - 먼데이피크닉: -0.3111
#   - 꽃보다크레페: -0.1716
#   - 라이언스커피로스터스: -0.2886
#   - 미드스트오브플로우: -0.5098
#   - Jesus Coffee: -0.5670
#   - 때가이르매: -0.5814
#   - 경성빵공장 카스테라점: -0.2730
#   - 틸데: -0.6948
#   - MUJABEE: -0.6470
#   - 없음 베이커리: -0.0269

# %% [markdown]
# # 최종 추천 결과

# %%
# final_results_by_input[input_text] 데이터를 딕셔너리로 변환
store_score_map = dict(final_results_by_input[input_text])

# 문자열 정규화 함수
def normalize_name(name):
    return name.strip().lower().replace(" ", "")

# final_results_by_input[input_text]에 있는 가게 이름을 user_store_scores에서 확인
for input_store, input_score in final_results_by_input[input_text]:
    matched = False
    normalized_input_store = normalize_name(input_store)
    for user, scores in user_store_scores.items():
        for store, score in scores:
            if normalize_name(store) == normalized_input_store:
                matched = True
                break
        if matched:
            break
    if not matched:
        print(f"Store mismatch: {input_store} not in user_store_scores")

# 사용자별 점수 업데이트 및 출력
for user, scores in user_store_scores.items():
    print(f"User: {user}")
    updated_scores = []
    for store, score in scores:
        # 사용자별 가게 이름을 final_results_by_input과 비교
        normalized_store = normalize_name(store)
        store_in_map = next((key for key in store_score_map if normalize_name(key) == normalized_store), None)

        if store_in_map:
            # 점수를 업데이트: store가 final_results_by_input에 있는 경우 더함
            updated_score = 2 * score + store_score_map[store_in_map]
            updated_scores.append((store, updated_score))
        else:
            updated_scores.append((store, 2 * score))
    # 업데이트된 점수로 정렬 후 상위 5개 선택
    updated_scores.sort(key=lambda x: x[1], reverse=True)
    top_5_scores = updated_scores[:5]
    for store, score in top_5_scores:
        print(f"  {store}: {score:.4f}")
    # 업데이트된 점수 리스트를 user_store_scores에 반영
    user_store_scores[user] = updated_scores
# Out:
# User: 369369z
#   더함: 4.1482
#   숙대소반: 2.6513
#   MUJABEE: 1.9715
#   Jesus Coffee: 1.9268
#   때가이르매: 1.8993
# User: A8뜨뚜
#   더함: 4.5841
#   숙대소반: 2.7980
#   카페 퓨엔테: 1.9835
#   와플하우스: 1.9722
#   위드달걀빵: 1.9460
# User: Chiabata
#   더함: 6.9383
#   숙대소반: 5.4123
#   미스터카츠 숙대입구점: 1.9978
#   샤브로21 숙명여대: 1.9608
#   나폴리키친: 1.9310
# User: DEJAVU
#   더함: 5.7491
#   숙대소반: 2.9781
#   카페나리나무: 1.9880
#   컴포즈커피 숙명여대점: 1.9253
#   루다브레드: 1.8185
# User: FromA
#   더함: 4.7999
#   숙대소반: 2.8030
#   키보 에다마메: 1.9500
#   벤티프레소 숙명여대점: 1.9411
#   루다브레드: 1.9259
# User: Junns
#   숙대소반: 5.5388
#   더함: 5.0178
#   뜸들이다 숙대점: 2.0024
#   옛날감자전: 1.9108
#   마시앤바시: 1.7593
# User: Reenfldos
#   더함: 4.3635
#   숙대소반: 3.4875
#   스택빈 숙대점: 1.8289
#   스타벅스 숙대점: 1.8113
#   킷테: 1.7215
# User: iamimmm
#   더함: 7.1089
#   숙대소반: 5.9629
#   샐러디 숙명여대점: 1.9597
#   이자와 숙대점: 1.9305
#   포라임 숙대본점: 1.8802
# User: lune93
#   더함: 5.9054
#   숙대소반: 3.1578
#   카페나리나무: 1.8746
#   컴포즈커피 숙명여대점: 1.8137
#   앙꼬: 1.8039
# User: ric****
#   더함: 4.1588
#   숙대소반: 3.3185
#   없음 베이커리: 1.9250
#   꽃보다크레페: 1.9072
#   옛날감자전: 1.8659
# User: u07****
#   더함: 6.0931
#   숙대소반: 3.3637
#   앙꼬: 1.7849
#   카페나리나무: 1.7820
#   가든한밤: 1.7451
# User: whrhwhdoo
#   더함: 3.4328
#   숙대소반: 3.3308
#   옛날감자전: 2.2401
#   메이드바이그레이스: 1.9354
#   때가이르매: 1.7907
# User: 김니00
#   더함: 4.8487
#   숙대소반: 4.4114
#   마시앤바시: 1.9458
#   킷테: 1.7945
#   스타벅스 숙대점: 1.4384
# User: 꿀맥주
#   더함: 4.1668
#   숙대소반: 2.7117
#   MUJABEE: 1.9179
#   와플하우스: 1.9022
#   틸데: 1.8520
# User: 대동맛지도
#   더함: 3.4856
#   숙대소반: 3.0679
#   틸데: 1.9559
#   때가이르매: 1.9421
#   미드스트오브플로우: 1.8552
# User: 데세헤
#   더함: 7.2564
#   숙대소반: 5.0899
#   장재근초밥: 1.9935
#   면식당 숙명여대점: 1.9802
#   포라임 숙대본점: 1.9531
# User: 도도는뚀
#   더함: 3.9116
#   숙대소반: 2.7603
#   미드스트오브플로우: 1.9941
#   Jesus Coffee: 1.9800
#   먼데이피크닉: 1.9712
# User: 돌고래삼촌
#   숙대소반: 5.5743
#   더함: 4.0825
#   옛날감자전: 3.3743
#   뜸들이다 숙대점: 2.8560
#   구복만두: 1.9972
# User: 딸기4282
#   더함: 4.8907
#   숙대소반: 3.8917
#   킷테: 1.9346
#   스타벅스 숙대점: 1.7809
#   스택빈 숙대점: 1.7718
# User: 뚝딱64
#   숙대소반: 5.0965
#   더함: 4.6196
#   마시앤바시: 1.9265
#   옛날감자전: 1.8849
#   뜸들이다 숙대점: 1.8123
# User: 리나4891
#   더함: 7.2601
#   숙대소반: 5.2117
#   장재근초밥: 1.9972
#   포라임 숙대본점: 1.9602
#   면식당 숙명여대점: 1.9428
# User: 리뷰꾸르잼
#   숙대소반: 6.1830
#   더함: 4.8935
#   옛날감자전: 2.9191
#   뜸들이다 숙대점: 2.8631
#   리또리또 숙대점: 1.9752
# User: 맛이써
#   숙대소반: 5.8578
#   더함: 4.5930
#   옛날감자전: 3.3540
#   뜸들이다 숙대점: 2.8560
#   김밥2000: 1.9886
# User: 맛있는거는 못참아
#   숙대소반: 4.3118
#   더함: 3.7091
#   옛날감자전: 3.0055
#   뜸들이다 숙대점: 1.8962
#   메이드바이그레이스: 1.8748
# User: 밍닝몽
#   숙대소반: 4.8020
#   더함: 4.3754
#   마시앤바시: 1.9643
#   옛날감자전: 1.8717
#   뜸들이다 숙대점: 1.6776
# User: 밤 새 피어난 비
#   숙대소반: 4.2496
#   더함: 3.7917
#   옛날감자전: 2.0666
#   마시앤바시: 1.7919
#   다이빙룸: 1.5813
# User: 봄 나무
#   더함: 7.2573
#   숙대소반: 5.1876
#   장재근초밥: 1.9964
#   포라임 숙대본점: 1.9557
#   면식당 숙명여대점: 1.9450
# User: 봄여름가을겨울그리고여름
#   더함: 5.2393
#   숙대소반: 4.4481
#   옛날감자전: 2.0078
#   홍곱창 숙명여대점: 1.8473
#   하이퐁가든: 1.4824
# User: 빼코빼코
#   더함: 4.3746
#   숙대소반: 2.7049
#   와플하우스: 1.9616
#   카페 퓨엔테: 1.9235
#   위드달걀빵: 1.9070
# User: 사랑스런백괘
#   더함: 4.7924
#   숙대소반: 2.8101
#   키보 에다마메: 1.9546
#   벤티프레소 숙명여대점: 1.9385
#   루다브레드: 1.9215
# User: 삼의미학
#   더함: 6.5617
#   숙대소반: 4.7612
#   미스터카츠 숙대입구점: 1.8151
#   샤브로21 숙명여대: 1.7449
#   나폴리키친: 1.5940
# User: 새댁528
#   더함: 4.8474
#   숙대소반: 2.6193
#   컴포즈커피 숙명여대점: 1.9666
#   와플하우스: 1.9190
#   위드달걀빵: 1.9080
# User: 샐연
#   더함: 5.6398
#   숙대소반: 2.9734
#   컴포즈커피 숙명여대점: 1.9078
#   카페나리나무: 1.8813
#   위드달걀빵: 1.8708
# User: 섹쉬올리브
#   더함: 5.8176
#   숙대소반: 3.0217
#   카페나리나무: 1.9898
#   컴포즈커피 숙명여대점: 1.9055
#   루다브레드: 1.7943
# User: 솔직담백 솔담씨의 리뷰스토리
#   숙대소반: 5.4242
#   더함: 4.7856
#   옛날감자전: 3.0703
#   뜸들이다 숙대점: 2.3417
#   솔티드 스모크: 1.9737
# User: 순진한깜박
#   더함: 7.0479
#   숙대소반: 4.4410
#   면식당 숙명여대점: 1.8978
#   베나레스 숙대점: 1.8896
#   탄막: 1.8559
# User: 스마일엘라
#   더함: 6.4949
#   숙대소반: 5.3840
#   몬스터플레이스: 1.9042
#   타코비 숙명여대점: 1.8173
#   홍곱창 숙명여대점: 1.7436
# User: 아보펭펭
#   더함: 4.9890
#   숙대소반: 4.9140
#   옛날감자전: 2.5854
#   홍곱창 숙명여대점: 1.9139
#   하이퐁가든: 1.8146
# User: 아암마시따
#   숙대소반: 5.6628
#   더함: 4.4550
#   옛날감자전: 2.7196
#   뜸들이다 숙대점: 2.5783
#   온센 용산구점: 1.7356
# User: 얄롱히
#   더함: 6.8623
#   숙대소반: 5.2732
#   미스터카츠 숙대입구점: 1.9813
#   샤브로21 숙명여대: 1.9326
#   나폴리키친: 1.8749
# User: 연마백
#   더함: 7.1518
#   숙대소반: 4.6710
#   면식당 숙명여대점: 1.9745
#   베나레스 숙대점: 1.9586
#   장재근초밥: 1.9121
# User: 잡덕수집가
#   더함: 4.3891
#   숙대소반: 2.5863
#   MUJABEE: 1.9519
#   Jesus Coffee: 1.9176
#   와플하우스: 1.8844
# User: 전국적인 먹짱
#   더함: 7.1222
#   숙대소반: 5.1647
#   몬스터플레이스: 1.9326
#   소소라면 닭꼬치: 1.9159
#   면식당 숙명여대점: 1.8903
# User: 지민5717
#   숙대소반: 5.9379
#   더함: 5.7539
#   사이공마켓 숙대점: 1.9237
#   뜸들이다 숙대점: 1.9203
#   옛날감자전: 1.6207
# User: 차차는
#   더함: 6.4671
#   숙대소반: 6.2553
#   옛날감자전: 2.0219
#   마포구이마당 숙대직영점: 1.9942
#   뜸들이다 숙대점: 1.9793
# User: 쿨제이95
#   더함: 5.7981
#   숙대소반: 3.1131
#   평화남영: 1.9755
#   루다브레드: 1.9332
#   카페나리나무: 1.9317
# User: 푸딩쓰
#   숙대소반: 4.3107
#   더함: 3.5596
#   옛날감자전: 3.0545
#   뜸들이다 숙대점: 1.9745
#   남영동양문 본점: 1.9287
# User: 화초까지먹을기세
#   더함: 4.6475
#   숙대소반: 2.6922
#   라이언스커피로스터스: 1.9110
#   키보 에다마메: 1.9052
#   루다브레드: 1.8955
# User: 황도0809
#   숙대소반: 5.7615
#   더함: 5.3592
#   뜸들이다 숙대점: 2.0021
#   옛날감자전: 1.8022
#   사이공마켓 숙대점: 1.7757
# User: 후암동 올리
#   숙대소반: 5.9164
#   더함: 5.7779
#   옛날감자전: 2.5492
#   뜸들이다 숙대점: 2.1571
#   타코비 숙명여대점: 1.9576
